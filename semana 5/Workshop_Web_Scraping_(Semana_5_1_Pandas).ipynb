# %% [markdown]
# # Workshop Web Scraping (Semana 5 - Pandas)

# %% [markdown]
# # Pandas DataFrames
# DataFrames no Pandas são uma estrutura de dados bidimensional (2-D) definida no pandas que consiste em linhas e colunas.

# %%
import pandas as pd

# %% [markdown]
# **Criando um DataFrame**
#
# Criação de data frame com os valores das series da oficina passada.

# %%
numeric_data = [1, 7, 2] # dado numérico

index = ["x", "y", "z"] # índices pré-definido

data = pd.Series(numeric_data, index)

df = pd.DataFrame(data)

print(df)
# Out:
#    0
# x  1
# y  7
# z  2

# %% [markdown]
# Aqui, data pode ser:
#
#
# 1.   Um ou mais dicionários
# 2.   uma ou mais Series
# 3.   2D-numpy Ndarray (Array multidimensional)
#
# Lembrando que index por padrão começa por 0: 0, 1, 2 ..., (n-1)

# %% [markdown]
# **Criar um DataFrame do Pandas a partir de vários dicionários**
#
# Criando um Dataframe com dois dicionários.

# %%
# Definição dicionario 1
dict1 = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# Definição dicionario 2
dict2 = {'a': 5, 'b': 6, 'c': 7, 'd': 8, 'e': 9}

# Definição de Data com dict1 e dict2
Data = {'primeiro': dict1, 'segundo': dict2}

# Create DataFrame
df = pd.DataFrame(Data)

print(df)
# Out:
#    primeiro  segundo
# a       1.0        5
# b       2.0        6
# c       3.0        7
# d       4.0        8
# e       NaN        9

# %% [markdown]
# **Converter lista de dicionários em um DataFrame do Pandas**
#
# Aqui, pegamos três dicionários e com a ajuda da função from_dict() os convertemos em Pandas DataFrame.

# %%
data_c = [
  {'A': 5, 'B': 0, 'C': 3, 'D': 3},
  {'A': 7, 'B': 9, 'C': 3, 'D': 5},
  {'A': 2, 'B': 4, 'C': 7, 'D': 6, 'E': 32}
 ]

df = pd.DataFrame.from_dict(data_c)

print(df)
# Out:
#    A  B  C  D     E
# 0  5  0  3  3   NaN
# 1  7  9  3  5   NaN
# 2  2  4  7  6  32.0

# %% [markdown]
# **Criar DataFrame de várias séries**
#
# Criando um dataframe de três séries.

# %%
# Definição da series 1
s1 = pd.Series([1, 3, 4, 5, 6, 2, 9])

# Definição da series 2
s2 = pd.Series([1.1, 3.5, 4.7, 5.8, 2.9, 9.3])

# Definição da series 3
s3 = pd.Series(['a', 'b', 'c', 'd', 'e'])

# Definição de Data
Data = {'primeiro':s1, 'segundo':s2, 'terceiro':s3}

# Criar DataFrame
df = pd.DataFrame(Data)

print(df)
# Out:
#    primeiro  segundo terceiro
# 0         1      1.1        a
# 1         3      3.5        b
# 2         4      4.7        c
# 3         5      5.8        d
# 4         6      2.9        e
# 5         2      9.3      NaN
# 6         9      NaN      NaN

# %% [markdown]
# **Converter um array em Pandas Dataframe**
#
# Ao criar um DataFrame de arrays 2D, as dimensões do array 2D devem ser as mesmas.

# %%
# Definição de array 2d 1
d1 =[[2, 3, 4], [5, 6, 7], [2,3,5]]

# Definição de array 2d 2
d2 =[[2, 4, 8], [1, 3, 9], [2.23343,'B',0]]

# Definição de Data
Data ={'primeiro': d1, 'segundo': d2}

# Create DataFrame
df_2d = pd.DataFrame(Data)

df_2d
# Out:
#     primeiro          segundo
# 0  [2, 3, 4]        [2, 4, 8]
# 1  [5, 6, 7]        [1, 3, 9]
# 2  [2, 3, 5]  [2.23343, B, 0]

# %% [markdown]
# # Acesso e Manipulação dos dados
#
# Lendo dados de um arquivo do tipo .csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fmassaretto/Workshop-WebScraping/main/arquivos/employees.csv")

#print(type(df))

#print(df)

#df.head(30)
df.tail(10)
# Out:
#      First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 991        Rose  Female   8/25/2002         5:12 AM  134505.0   11.051
# 992     Anthony    Male  10/16/2011         8:35 AM  112769.0   11.625
# 993        Tina  Female   5/15/1997         3:53 PM   56450.0   19.040
# 994      George    Male   6/21/2013         5:47 PM   98874.0    4.479
# 995       Henry     NaN  11/23/2014         6:09 AM  132483.0   16.655
# 996     Phillip    Male   1/31/1984         6:30 AM   42392.0   19.675
# 997     Russell    Male   5/20/2013        12:39 PM   96914.0    1.421
# 998       Larry    Male   4/20/2013         4:45 PM   60500.0   11.985
# 999         NaN     NaN         NaN             NaN       NaN      NaN
# 1000     Albert    Male   5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# 991               True             Marketing
# 992               True               Finance
# 993               True           Engineering
# ...

# %% [markdown]
# **isnull**
#
# Conferindo quais valores sao nulos, retorna true se o valor for nulo e false se tem algum valor na celula

# %%
df.isnull()
# Out:
#       First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0          False   False       False            False   False    False
# 1          False   False       False            False   False    False
# 2          False   False       False            False   False    False
# 3          False   False       False            False   False    False
# 4          False   False       False            False   False    False
# ...          ...     ...         ...              ...     ...      ...
# 996        False   False       False            False   False    False
# 997        False   False       False            False   False    False
# 998        False   False       False            False   False    False
# 999         True    True        True             True    True     True
# 1000       False   False       False            False   False    False
#
#       Senior Management   Team
# 0                 False  False
# 1                 False   True
# ...

# %% [markdown]
# **fillna**
#
# Preeenchendo um valor que você definir no lugar dos valores nulos (no caso do pandas, ele substitui nulo (None) por NaN (Not a Number))

# %%
# df["Gender"].fillna("sem valor") # substirui um campo nulo (NaN) de uma coluna específica
df.fillna("nao ok", inplace = True) # substirui um campo nulo (NaN) de todo o dataframe
df.tail(50)
# Out:
# <ipython-input-16-97f9617c533f>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nao ok' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("nao ok", inplace = True) # substirui um campo nulo (NaN) de todo o dataframe
#      First Name  Gender  Start Date Last Login Time    Salary Bonus %  \
# 951      nao ok  Female   9/14/2010         5:19 AM  143638.0   9.662
# 952      Teresa  Female   1/22/2013         3:17 PM  113425.0  11.907
# 953       Randy    Male   2/25/2012         5:33 AM   57266.0  14.077
# 954         Joe    Male   1/19/1980         4:06 PM  119667.0   1.148
# 955       Sarah  Female   8/17/2014        11:08 PM  127118.0  11.176
# 956     Beverly  Female  10/17/1986        12:51 AM   80838.0   8.115
# 957     Jeffrey    Male    2/3/1984         1:26 PM   70990.0  15.901
# ...

# %% [markdown]
# **dropna**
#
# Remove linhas que contenham valor ou valores nulos

# %%
df = df.dropna() # remove qualquer linha que tenha pelo menos um valor nulo
df
# Out:
#      First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308.0    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590.0   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705.0    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004.0    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163.0   10.125
# ...         ...     ...        ...             ...       ...      ...
# 994      George    Male  6/21/2013         5:47 PM   98874.0    4.479
# 996     Phillip    Male  1/31/1984         6:30 AM   42392.0   19.675
# 997     Russell    Male  5/20/2013        12:39 PM   96914.0    1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert    Male  5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
data = df.dropna(how = 'all') # remove a linha em que todos os valores são nulos
data
# Out:
#      First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308.0    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590.0   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705.0    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004.0    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163.0   10.125
# ...         ...     ...        ...             ...       ...      ...
# 994      George    Male  6/21/2013         5:47 PM   98874.0    4.479
# 996     Phillip    Male  1/31/1984         6:30 AM   42392.0   19.675
# 997     Russell    Male  5/20/2013        12:39 PM   96914.0    1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert    Male  5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# **loc e iloc**
#
# loc e iloc são utilizados para fatiar (separar) um conjunto de dados de um dataframe.
#
# Com loc, conseguimos acessar multiplas colunas e fazer alguma logica que só retorne os dados que queremos analisar.

# %%
df.loc[df['Gender'] == 'Male']
# Out:
#      First Name Gender Start Date Last Login Time    Salary  Bonus %  \
# 0       Douglas   Male   8/6/1993        12:42 PM   97308.0    6.945
# 3         Jerry   Male   3/4/2005         1:00 PM  138705.0    9.340
# 4         Larry   Male  1/24/1998         4:47 PM  101004.0    1.389
# 5        Dennis   Male  4/18/1987         1:35 AM  115163.0   10.125
# 12      Brandon   Male  12/1/1980         1:08 AM  112807.0   17.492
# ...         ...    ...        ...             ...       ...      ...
# 994      George   Male  6/21/2013         5:47 PM   98874.0    4.479
# 996     Phillip   Male  1/31/1984         6:30 AM   42392.0   19.675
# 997     Russell   Male  5/20/2013        12:39 PM   96914.0    1.421
# 998       Larry   Male  4/20/2013         4:45 PM   60500.0   11.985
# 1000     Albert   Male  5/15/2012         6:24 PM  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 3                 True               Finance
# ...

# %%
df.loc[(df['Gender'] == 'Male') & (df['Salary'] > 100000.0)].head()
# Out:
#    First Name Gender Start Date Last Login Time    Salary  Bonus %  \
# 3       Jerry   Male   3/4/2005         1:00 PM  138705.0    9.340
# 4       Larry   Male  1/24/1998         4:47 PM  101004.0    1.389
# 5      Dennis   Male  4/18/1987         1:35 AM  115163.0   10.125
# 12    Brandon   Male  12/1/1980         1:08 AM  112807.0   17.492
# 13       Gary   Male  1/27/2008        11:40 PM  109831.0    5.831
#
#    Senior Management             Team
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal
# 12              True  Human Resources
# 13             False            Sales

# %%
df.loc[0:10, ['First Name','Salary']]
# Out:
#   First Name    Salary
# 0    Douglas   97308.0
# 2      Maria  130590.0
# 3      Jerry  138705.0
# 4      Larry  101004.0
# 5     Dennis  115163.0
# 6       Ruby   65476.0
# 8     Angela   95570.0
# 9    Frances  139852.0

# %% [markdown]
# iloc é baseado na posição onde quero encontrar o dado, ex.:

# %%
df.iloc[0, 4]
# Out:
# 97308.0

# %% [markdown]
# sendo,
#
# primeiro parametro: linha=0
#
# segundo parametro: coluna=4
#
# Também posso ter uma faixa de dados, ex.:

# %%
df.iloc[0:5, 3:6]
# Out:
#   Last Login Time    Salary  Bonus %
# 0        12:42 PM   97308.0    6.945
# 1         6:53 AM   61933.0    4.170
# 2        11:17 AM  130590.0   11.858
# 3         1:00 PM  138705.0    9.340
# 4         4:47 PM  101004.0    1.389

# %% [markdown]
# **Query**
#
# Permite fazer consultas no dataframe procurando por um valor específico

# %%
df.query('`First Name` == "Maria"')['Salary'] # Atenção: metodo query, quando o nome da coluna tem espaço usamos acento grave (`)
                                              # ao invés de aspas simples ou dupla

# extra: com o metodo describe conseguimos ter uma análise estatística
# df.query('`First Name` == "Maria"')['Salary'].describe()
# Out:
# 2      130590.0
# 198     36067.0
# 936     96250.0
# 984     43455.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Exercício
#
# 1.   Ler o arquivo csv: https://raw.githubusercontent.com/fmassaretto/Workshop-WebScraping/main/arquivos/TabelaA%C3%A7%C3%B5es.csv
# 2.   Remover todos os valores nulos
# 3. Aplicar a seguinte lógica: retornar os dados que o "Val. Min" seja maior que 20.0, o "Val. Max" menor que 50.0 e "Var. Ano (%)" seja positivo
